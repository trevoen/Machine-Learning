# %% [markdown]
# # Trabalho Pratico 2 - Otimizacao e Interpretabilidade
#
# Este notebook executa o pipeline implementado em `src/t2_hyperparameter_optimization.py`.
#
# A implementacao parte do CSV bruto, remove a classe indefinida (`Overall == 0`), remove labels auxiliares (`TA98`, `TA100`, `TA102`, `TA1535`, `TA1537`) das features e usa `Pipeline` para manter imputacao, selecao de baixa variancia e normalizacao dentro da validacao cruzada.

# %% [markdown]
# ## Execucao completa
#
# A execucao padrao usa perfil pragmatico para evitar configuracoes muito custosas. Para uma busca mais longa, use `--search-profile robust` e aumente `--trials`.

# %%
# %run ../src/t2_hyperparameter_optimization.py --trials 100 --cv-folds 5 --importance-repeats 10

# %% [markdown]
# ## Artefatos gerados
#
# - `results/metrics/t2/optimization_summary.csv`
# - `results/metrics/t2/final_test_results.csv`
# - `results/metrics/t2/permutation_importance_<modelo>.csv`
# - `results/figures/t2/optimized_models_test_comparison.png`
# - `results/figures/t2/confusion_matrix_<modelo>.png`
# - `results/figures/t2/roc_curve_<modelo>.png`
# - `results/figures/t2/permutation_importance_<modelo>.png`
